# %% [markdown]
# Сборник постепенно дополняется новыми материалами.

# %% [markdown]
# [**ДА вздрогнет FAANG, или практическое руководство по поиску работы в США/Европе для айтишника**](https://habr.com/ru/company/smart_start/blog/472796/)
#
# FAANG - это сокращение от "Facebook, Amazon, Apple, Netflix и Google", условно используется в отношении любой крупной IT-компании. Сама статья о поиске работы в США через нетворкинг, то есть личные знакомства и рекомендации. Много полезной информации.
#
# Цитаты из статьи и комментариев:
#
# - "Сайты со списком вакансий — один из самых низкоэффективных способов, по крайней мере в США. ... Большинство позиций в FAANG закрывается с помощью реферальных рекомендаций. Для многих — это не только отличная возможность обойти жесткие pre-screening программы, которые способны «зарезать» даже топ-специалистов, но и существенная экономия времени. ... В корпоративной Америке нетворкинг имеет колоссальное значение. ... В общих чертах процесс выглядит так: ищем позицию — ищем контакт из компании — готовим убойное резюме/cover letter под конкретную позицию — подаем документы — проходим серию интервью."
# - "Очень рекомендую воспользоваться платным фидбеком на том же Rooftopslushie.com, чтобы составить идеальное резюме. Многие ребята из СНГ делают его совершенно неправильно. ... Резюме должно быть максимально заточено под желаемую позицию."
# - "никогда не спешите с зарплатой. Пытайтесь узнать «range» у рекрутеров, прежде чем давать свои личные предпочтения."
# - "Даже для американцев (которым не нужно спонсорство с h1b визой) одна из самых больших проблем — именно попадание на интервью. Потому что скрининговые системы — очень жёстки и малопредсказумы."

# %% [markdown]
# [**Подготовка к собеседованиям в IT-гиганты: как я преодолела проклятье алгоритмического собеседования**](https://habr.com/ru/post/499394/)
#
# Подробно о том, как IT-компании принимают на работу: отдельно по каждой компании, с картинками и схемами.
#
# Цитаты из статьи и комментариев:
#
# - "полгода-год - примерно через такой период компании разрешают подаваться снова"
# - "Общий подход у Google и, например, Microsoft — разделение процесса для кандидатов с минимальным опытом работы (< 1 года) и опытных кандидатов. Для первых может дополнительно проводиться онлайн-тестирование (online assessment)."
# - "Google один из лидеров по количеству сессий — целых пять на очном этапе, а потом ещё одно или несколько собеседований с командой."
# - "Самый оригинальный процесс у Facebook — выбор команды происходит уже после найма. Новый сотрудник 6 недель проводит в bootcamp — это тестовые проекты в разных командах, а затем принимает решение."
# - "Я готовилась с помощью Leetcode ... Выбирала в основном задачи среднего уровня, так как сложные спрашивают довольно редко. ... C платной подпиской там можно просмотреть специальные подборки задач по популярным компаниям и они помогают быстро подготовиться."
# - "придётся объяснять свой ход мыслей по-английски и делать это параллельно написанию кода"
# - "Информации по подготовке к system design собеседованию в разы меньше, чем к алгоритмическому. ... этот этап важен для оценки «сениорности» кандидата."
# - "перестали спрашивать про теннисные мячи в автобусе, это все-таки уже ближе к реальности. И тенденция идет в сторону менее «красивых» и более прикладных задач."
# - "Вот я так же к устройству в гугл готовился-готовился, на собеседовании ответил хорошо и взяли меня на позицию выше, чем я заслуживал. Чуть не выперли потом, еле выкарабкался."

# %% [markdown]
# [**Искусство войны ML инженера с FAANG**](https://habr.com/ru/post/579410/)
#
# Статья о том, как у автора проходили собеседования на должности, связанные с ML, в самые разные компании, а именно TikTok, Apple, NVIDIA, LinkedIn и другие.
#
# Из комментариев:
#
# - "FAANG перевозит без вопросов, у них как раз нет проблемы оформить визу. Просто у них есть принцип, что лучше отказать хорошему кандидату, чем случайно взять плохого. Вот и доля отказов очень большая. Если есть сомнения — отказывают."

# %% [markdown]
# [**Как айтишнику найти работу в США и ЕС: 9 лучших ресурсов**](https://habr.com/ru/post/421595/)
#
# Статья о том, о чем заголовок. Не длинная, но информативная. Для тех, кто непосредственно занят поиском работы.

# %% [markdown]
# [**Поиск работы в США: «Силиконовая Долина»**](https://habr.com/ru/post/290776/)
#
# Рассмотрены разные типы рекрутеров, формат интервью и прочее в деталях.
#
# Цитаты из статьи и комментариев:
#
# - "Перед тем как решить искать работу в США имеет смысл ознакомится с требованиями по эмиграции и права на работу в США."
# - "Правила хорошего тона предполагают, что вы хорошо знакомы с продуктом компании из этого следует и исходить задавая вопросы."
# - "Если повезет - дождаться второго «оффера». Тогда у вас появляется уникальная возможность диктовать свои требования нанимающей компании."
# - "Собственно пиво можно начинать пить еще до начала интервью, старайтесь получить как можно больше положительных эмоций от поиска работы."
# - "у меня первые три года по приезду была удаленнка. Встречались обычно в ресторане раз в неделю. Двольно быстро надоедает и тянет в офис"
# - "что лучше сделать заранее до поиска работы? сертификация, контрибьюшин в опен соурс, свой блог, свой гитхаб с образцами кода, английский язык"
# - "Сертификаты [по английскому] не нужны. Нужно просто внятно объяснять на англиском языке, что хотите сказать и понимать, что Вам сказали."
